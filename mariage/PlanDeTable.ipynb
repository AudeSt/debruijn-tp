# %%
import pandas as pd

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/u/0/d/1DqexWH8S3IQqP3uesAA6X9I0f2jhRjhLRICbdzEci8A/export?format=csv&id=1DqexWH8S3IQqP3uesAA6X9I0f2jhRjhLRICbdzEci8A&gid=0')
test.head(5)
# Out:
#        NOM        Prénom                Qualité     Age  AnnéeNaissance  \
# 0  STERLIN          Aude                 Mariée  Adulte          1998.0
# 1  THOMAZO        Michel                  Marié  Adulte          1998.0
# 2  STERLIN        Hugues  Famille proche mariée  Adulte             NaN
# 3  STERLIN  Claire-Elise  Famille proche mariée  Adulte             NaN
# 4  STERLIN      Ombeline  Famille proche mariée  Adulte          1994.0
#
#    Age_jeune_adulte Couple NOM_rattachement Prénom_rattachement
# 0              23.0    oui          THOMAZO              Michel
# 1              23.0    oui          STERLIN                Aude
# 2               NaN    oui          STERLIN        Claire-Elise
# 3               NaN    oui          STERLIN              Hugues
# 4              27.0    non              NaN                 NaN
