# %%
import pandas as pd

# %%
test = pd.read_csv('https://docs.google.com/spreadsheets/u/0/d/1DqexWH8S3IQqP3uesAA6X9I0f2jhRjhLRICbdzEci8A/export?format=csv&id=1DqexWH8S3IQqP3uesAA6X9I0f2jhRjhLRICbdzEci8A&gid=0',
                   # Set first column as rownames in data frame
                   index_col=0, sep=','
                  )
test.head(5)
# Out:
#                Prénom                Qualité     Age AnnéeNaissance  \
# NOM
# STERLIN          Aude                 Mariée  Adulte           1998
# THOMAZO        Michel                  Marié  Adulte           1998
# STERLIN        Hugues  Famille proche mariée  Adulte           None
# STERLIN  Claire-Elise  Famille proche mariée  Adulte           None
# STERLIN      Ombeline  Famille proche mariée  Adulte           1994
#
#         Age_jeune_adulte Couple NOM_rattachement Prénom_rattachement
# NOM
# STERLIN               23    oui          THOMAZO              Michel
# THOMAZO               23    oui          STERLIN                Aude
# STERLIN             None    oui          STERLIN        Claire-Elise
# STERLIN             None    oui          STERLIN              Hugues
# STERLIN               27    non             None                None

# %%
test = pd.read_csv("InvitesDiner.csv")

test.head()
# Out:
#        NOM        Prénom                Qualité     Age AnnéeNaissance  \
# 0  STERLIN          Aude                 Mariée  Adulte           1998
# 1  THOMAZO        Michel                  Marié  Adulte           1998
# 2  STERLIN        Hugues  Famille proche mariée  Adulte           None
# 3  STERLIN  Claire-Elise  Famille proche mariée  Adulte           None
# 4  STERLIN      Ombeline  Famille proche mariée  Adulte           1994
#
#   Age_jeune_adulte Couple NOM_rattachement Prénom_rattachement
# 0               23    oui          THOMAZO              Michel
# 1               23    oui          STERLIN                Aude
# 2             None    oui          STERLIN        Claire-Elise
# 3             None    oui          STERLIN              Hugues
# 4               27    non             None                None
